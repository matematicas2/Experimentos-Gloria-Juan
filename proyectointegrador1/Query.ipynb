# %%
import pickle
import pandas as pd
from math import log
import re
import nltk
nltk.download(['punkt','stopwords','wordnet','words'])
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
import metapy
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\cmejia\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\cmejia\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\cmejia\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\cmejia\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %% [markdown]
# # Cargar el modelo de datos

# %%
loaded_model = pickle.load(open('estructuraDatos.sav', 'rb'))
idexFiles = loaded_model['idexFiles']
vectorizer = loaded_model['vectorizer']
matrix = loaded_model['matriz']
indexMeta = loaded_model['metapyIndex']

# %% [markdown]
# # Rankin solo por conteo sin indice invertido

# %%
# Encontrar los documentos que contiene una palabra en particular
def encontrarDoc(palabra):
    col = vectorizer.vocabulary_[palabra]
    matx = matrix[:,col]
    indx = matx.nonzero()[0]
    lista =indx.tolist() 
    dfresult = pd.DataFrame()
    for i in range(len(lista)):
        auxres= pd.DataFrame({'NombreArchivo': idexFiles[lista[i]], 'Frecuencia': [matx.data[i]]})
        dfresult = pd.concat([dfresult, auxres])
    dfresult.sort_values('Frecuencia',ascending = False,inplace = True)
    return dfresult

# %% [markdown]
# # Construcción del índice invertido

# %%
def indice_invertido(dic):
    inv = {}
    N = matrix.shape[0]
    for k, v in vectorizer.vocabulary_.items():
        inv.setdefault(k, {})
        #Los documentos que contienen la palabra v
        matx = matrix[:,v]
        #Indicador de los documentos que contienen la palabra
        indx = matx.nonzero()[0]
        lista =indx.tolist()
        docs = {}
        if len(lista)== 0:
            print(k)
        else:
            #Calculo del IDF, lista contiene todos los documentos que contienen la palabra
            inv[k]['IDF'] = log((N+1)/(len(lista)))
            for i in range(len(lista)):
                keys = docs.setdefault(idexFiles[lista[i]], [])
                #Frecuencia de la palabra V en el documento lista[i]
                keys.append(matx.data[i])
                #Las palabras que contiene el documento lista[i]
                matx2 = matrix[lista[i],:]
                #La frecuencia de cada palabra, que sumada el vector da el total de palabras en el documento
                keys.append(matx2.data.sum())
        inv[k]['Documentos'] = docs
    return inv

# %%
ind_inv = indice_invertido(vectorizer.vocabulary_)
# Out:
# across
# all
# almost
# along
# also
# although
# among
# amongst
# amount
# and
# anyhow
# anyway
# around
# back
# be
# beforehand
# behind
# between
# beyond
# bill
# both
# bottom
# call
# can
# cannot
# cant
# con
# could
# de
# detail
# do
# eight
# either
# eleven
# enough
# even
# except
# fifteen
# fill
# find
# fire
# first
# five
# former
# found
# front
# full
# further
# get
# give
# go
# have
# here
# herein
# how
# in
# interest
# it
# keep
# last
# latter
# least
# less
# might
# mine
# move
# must
# name
# neither
# never
# nevertheless
# next
# nor
# nothing
# off
# often
# one
# onto
# other
# out
# over
# own
# part
# per
# put
# rather
# same
# see
# seem
# serious
# show
# side
# somehow
# still
# system
# take
# ten
# then
# therein
# these
# thick
# thin
# third
# though
# three
# throughout
# thru
# top
# toward
# two
# under
# upon
# well
# where
# wherein
# whereupon
# whether
# whoever
# whole
# whose
# with
# within
# without
# would

# %% [markdown]
# # Función de limpieza del query

# %%
stopWords = stopwords.words('english')
def queryClean(texto):
    #Pasar todo a minisculas
    texto = texto.lower()
    texto =re.sub('(á|à|ä)','a',texto) # Reemplazar a acentuada
    texto =re.sub('(é|è|ë)','e',texto) # Reemplazar e acentuada
    texto =re.sub('(í|ì|ï)','i',texto) # Reemplazar i acentuada
    texto =re.sub('(ó|ò|ö)','o',texto) # Reemplazar o acentuada
    texto =re.sub('(ú|ù|ü)','u',texto) # Reemplazar u acentuada
    texto =re.sub('[^a-zA-Z]',' ',texto) # Eliminar caracteres que no sean: letra, número o vocales acentuadas
    texto =re.sub(' +',' ',texto) # Eliminar espacios en blanco
    #Tokenizar
    tokens = texto.split()
    tokens = [w for w in tokens if (len(w)>1)&(w.isalpha())&(w not in stopWords)]
    #Lemma
    word_net_lemmatizar = WordNetLemmatizer()
    tokens = [word_net_lemmatizar.lemmatize(w, pos = "v") for w in tokens]

    #Stemmer
    ps = PorterStemmer() 
    tokens = [ps.stem(w) for w in tokens]

    return tokens

# %% [markdown]
# # Rankin por Term Frequency

# %%
def queryTF(word,top):
    respuesta = sorted(ind_inv[word]['Documentos'].items(), key = lambda kv:(kv[1], kv[0]),reverse=True)
    return respuesta[0:top]

# %% [markdown]
# # Rankin por Term Frequency / Doc Length

# %%
def queryTFDL(word,top):
    aux = ind_inv[word]['Documentos']
    auxdic = {}
    for k,v in aux.items():
        keys = auxdic.setdefault(k, [])
        keys.append(v[0]/v[1])
    respuesta = sorted(auxdic.items(), key = lambda kv:(kv[1], kv[0]),reverse=True)
    return respuesta[0:top]

# %% [markdown]
# # Rankin usando BM25

# %%
def cal_bm25(idf,frec,k,b,length,avgdl):
    aux = idf*((frec*(k+1))/(frec+k*(1-b+b*length/avgdl)))
    return aux

# %%
def queryBM25(query, vocabulary, prom, k1, b, top):
    query_word = queryClean(query)
    dfresultb25 = pd.DataFrame()
    resultadoBm25 = pd.DataFrame()
    for word in query_word:
        if (word in vocabulary):
            aux = ind_inv[word]['Documentos']
            IDF = ind_inv[word]['IDF']
            for k,v in aux.items():
            #     keys = bm25.setdefault(k, [])
                aux25 = cal_bm25(IDF,v[0],k1,b,v[1],prom)
                auxresb25= pd.DataFrame({'NombreArchivo': k.split('\\')[-1], 'Word': word, 'BM25' : [aux25]})
                dfresultb25 = pd.concat([dfresultb25, auxresb25])
            resultadoBm25 = dfresultb25.groupby('NombreArchivo').agg({'BM25':'sum'}).sort_values('BM25',ascending = False).reset_index()
            resultadoBm25.reset_index(inplace = True)
            resultadoBm25.rename(columns = {'index':'Ranking'}, inplace = True)
        else:
            print(f'{word} is not in the vocabulary')
    return resultadoBm25.head(top)

# %% [markdown]
# ### Definición de parámetros para el BM25

# %%
top = 20
prom = 27544.226762002043
k1 = 1.2
b = 0.75
vocabulary = vectorizer.vocabulary_

# %% [markdown]
# # Metapy

# %%
inv_idx = metapy.index.make_inverted_index('cranfield.toml')

# %%
print(f'Total de documentos: {inv_idx.num_docs()}')
print(f'Cantidad de palabras únicas: {inv_idx.unique_terms()}')
print(f'Promedio de longitud de los documentos: {inv_idx.avg_doc_length()}')
# Out:
# Total de documentos: 980
# Cantidad de palabras únicas: 51229
# Promedio de longitud de los documentos: 3984.62646484375

# %% [markdown]
# # Metapy Rankin

# %%
def rankerMeta(top, querywords):
    ranker = metapy.index.OkapiBM25(k1 = k1, b = b)
    query = metapy.index.Document()
    query.content(querywords) # query from AP news
    top_docs = ranker.score(inv_idx, query, num_results=top)
    metaresult = pd.DataFrame()
    for doc in top_docs:
        auxmeta= pd.DataFrame({'NombreArchivo': indexMeta[doc[0]],  'BM25_Meta' : [doc[1]]})
        metaresult = pd.concat([metaresult, auxmeta])
    metaresult = metaresult.reset_index(drop = True).reset_index()
    metaresult.rename(columns = {'index':'RankingMeta'},inplace = True)
    return metaresult

# %% [markdown]
# # Evaluación de los queries

# %%
def calculate_sens(queries,top):
    sens = pd.DataFrame()
    for query in queries:
        resultados = queryBM25(query, vocabulary, prom, k1, b,top)
        metares = rankerMeta(top, query)
        merget = resultados.merge(metares, how = 'left', on = 'NombreArchivo')
        sensibilidad = (merget['RankingMeta']>=0).sum()/len(merget)
        auxsens= pd.DataFrame({'Query': query,  'Sensibilidad' : [sensibilidad]})
        sens = pd.concat([sens, auxsens])
    return sens

# %%
queries = ["Data Science","Machine Learning", "Math","Computer Science","Algorithms in dynamic networks", "triangle free process"]
sensibilidad = calculate_sens(queries,top)
# Out:
# data is not in the vocabulary

# %%
sensibilidad
# Out:
#                             Query  Sensibilidad
# 0                    Data Science          0.70
# 0                Machine Learning          0.95
# 0                            Math          0.75
# 0                Computer Science          0.65
# 0  Algorithms in dynamic networks          0.85
# 0           triangle free process          0.75

# %%
query = "Algorithms in dynamic networks"

# %%
resultados = queryBM25(query, vocabulary, prom, k1, b,top)
metares = rankerMeta(top, query)

# %%
resultados.merge(metares, how = 'left', on = 'NombreArchivo')
# Out:
#     Ranking   NombreArchivo      BM25  RankingMeta  BM25_Meta
# 0         0   1412.4171.txt  4.843937          0.0   4.719563
# 1         1   1005.2894.txt  4.827652          1.0   4.667416
# 2         2  1511.02476.txt  4.806497         15.0   4.473639
# 3         3  1504.03957.txt  4.790875          4.0   4.589195
# 4         4   1204.1160.txt  4.782933          2.0   4.621671
# 5         5   1411.4097.txt  4.776740          6.0   4.559735
# 6         6  1502.04382.txt  4.768490         12.0   4.508224
# 7         7   1412.0291.txt  4.766188         16.0   4.472593
# 8         8  1502.02908.txt  4.760860          7.0   4.542059
# 9         9   1310.3389.txt  4.745049          3.0   4.603845
# 10       10  1509.01676.txt  4.740706          9.0   4.521289
# 11       11  1502.05767.txt  4.733042          NaN        NaN
# 12       12   1304.3944.txt  4.719008         10.0   4.514637
# 13       13  1509.03484.txt  4.718459          8.0   4.524240
# 14       14   1406.5688.txt  4.713706         18.0   4.443789
# 15       15   1410.0446.txt  4.710436          5.0   4.572094
# 16       16   1403.1080.txt  4.709085          NaN        NaN
# 17       17   1001.1435.txt  4.706690         11.0   4.511307
# 18       18  1510.05071.txt  4.703365         14.0   4.477984
# 19       19  1511.00867.txt  4.699554          NaN        NaN

# %%
gruposbydoc = pd.read_csv('docByCluster.csv')

# %% [markdown]
# ## Documentos cercanos

# %%
gruposbydoc[gruposbydoc['cluster']==cluster]
# Out:
#                           identifier  \
# 8     http://arxiv.org/abs/0903.0197
# 9     http://arxiv.org/abs/0903.0199
# 17    http://arxiv.org/abs/0910.5577
# 34    http://arxiv.org/abs/1006.1029
# 41    http://arxiv.org/abs/1012.4019
# 43    http://arxiv.org/abs/1101.1169
# 54    http://arxiv.org/abs/1104.0746
# 57    http://arxiv.org/abs/1104.4987
# 61    http://arxiv.org/abs/1106.1445
# 67    http://arxiv.org/abs/1108.1915
# 85    http://arxiv.org/abs/1201.5921
# 101   http://arxiv.org/abs/1204.0480
# 108   http://arxiv.org/abs/1204.3850
# 113   http://arxiv.org/abs/1205.5770
# 114   http://arxiv.org/abs/1205.6363
# 120   http://arxiv.org/abs/1206.4809
# 123   http://arxiv.org/abs/1208.3124
# 128   http://arxiv.org/abs/1209.1711
# 131   http://arxiv.org/abs/1209.6626
# 134   http://arxiv.org/abs/1210.2540
# 139   http://arxiv.org/abs/1210.7638
# 140   http://arxiv.org/abs/1211.0071
# 142   http://arxiv.org/abs/1211.0729
# 152   http://arxiv.org/abs/1212.1095
# 155   http://arxiv.org/abs/1212.6751
# 158   http://arxiv.org/abs/1301.1071
# 164   http://arxiv.org/abs/1301.5293
# 172   http://arxiv.org/abs/1302.6325
# 174   http://arxiv.org/abs/1303.0926
# 190   http://arxiv.org/abs/1305.0750
# ..                               ...
# 658  http://arxiv.org/abs/1505.02214
# 666  http://arxiv.org/abs/1505.04036
# 714  http://arxiv.org/abs/1506.06055
# 729  http://arxiv.org/abs/1506.08752
# 734  http://arxiv.org/abs/1507.01089
# 743  http://arxiv.org/abs/1507.02184
# 749  http://arxiv.org/abs/1507.03344
# 765  http://arxiv.org/abs/1507.06011
# 784  http://arxiv.org/abs/1508.01775
# 789  http://arxiv.org/abs/1508.02521
# 791  http://arxiv.org/abs/1508.02759
# 797  http://arxiv.org/abs/1508.03773
# 818  http://arxiv.org/abs/1509.00864
# 819  http://arxiv.org/abs/1509.00926
# 820  http://arxiv.org/abs/1509.01347
# 825  http://arxiv.org/abs/1509.02601
# 841  http://arxiv.org/abs/1509.05821
# 849  http://arxiv.org/abs/1509.07552
# 853  http://arxiv.org/abs/1509.08690
# 858  http://arxiv.org/abs/1509.09188
# 863  http://arxiv.org/abs/1510.01072
# 875  http://arxiv.org/abs/1510.02787
# 894  http://arxiv.org/abs/1510.05278
# 910  http://arxiv.org/abs/1510.08578
# 912  http://arxiv.org/abs/1510.08797
# 931  http://arxiv.org/abs/1511.02166
# 939  http://arxiv.org/abs/1511.03407
# 940  http://arxiv.org/abs/1511.03501
# 958  http://arxiv.org/abs/1511.06436
# 964  http://arxiv.org/abs/1511.07174
#
#                                                  title  \
# 8       Rotation Distance is Fixed-Parameter Tractable
# 9    A Linear-Time Approximation Algorithm for Rota...
# 17   On the stability of two-chunk file-sharing sys...
# 34   Chi-square-based scoring function for categori...
# 41   Constructing elliptic curve isogenies in quant...
# 43   Almost Settling the Hardness of Noncommutative...
# 54   Quantifier Elimination over Finite Fields Usin...
# 57   An improved bound on the number of point-surfa...
# 61            From Classical to Quantum Shannon Theory
# 67   Noise effects in the quantum search algorithm ...
# 85   An iterative algorithm for parametrization of ...
# 101  Deducing Security Goals From Shape Analysis Se...
# 108  Simple Agents Learn to Find Their Way: An Intr...
# 113  Randomized Extended Kaczmarz for Solving Least...
# 114  What Should Developers Be Aware Of? An Empiric...
# 120  Connected Choice and the Brouwer Fixed Point T...
# 123  On the computation of zone and double zone dia...
# 128     Programming Languages for Scientific Computing
# 131  On Newton-Raphson iteration for multiplicative...
# 134  On the Automorphism Group of a Binary Self-dua...
# 139  Finding Efficient Region in The Plane with Lin...
# 140                     Randomness and Non-determinism
# 142              A Simple Algorithm for Computing BOCP
# 152  The projector algorithm: a simple parallel alg...
# 155  Computably Categorical Fields via Fermat's Las...
# 158  Direct QR factorizations for tall-and-skinny m...
# 164         Approximately counting semismooth integers
# 172  A Note on "A polynomial-time algorithm for glo...
# 174  Injectivity w.r.t. Distribution of Elements in...
# 190                      Multi-Sided Boundary Labeling
# ..                                                 ...
# 658  An Empirical Study of Leading Measures of Depe...
# 666  Unified way for computing dynamics of Bose-Ein...
# 714  Low PMEPR OFDM radar waveform design using the...
# 729  On Tightly Bounding the Dubins Traveling Sales...
# 734  (Pure) transcendence bases in $\phi$-deformed ...
# 743  The "art of trellis decoding" is fixed-paramet...
# 749       Entanglement in Reversible Quantum Computing
# 765  Using coarse GPS data to quantify city-scale t...
# 784  Cascading Power Outages Propagate Locally in a...
# 789  Topology Control of wireless sensor network us...
# 791  Technical Note: Split Algorithm in O(n) for th...
# 797               No acute tetrahedron is an 8-reptile
# 818          Strong Pseudoprimes to Twelve Prime Bases
# 819  Using Inclusion Diagrams as an Alternative to ...
# 820  Verificarlo: checking floating point accuracy ...
# 825        On the $O_\beta$-hull of a planar point set
# 841  New bounds on curve tangencies and orthogonali...
# 849  Formal Support for Standardizing Protocols wit...
# 853  Kempe's Universality Theorem for Rational Spac...
# 858  Approximate Spectral Clustering: Efficiency an...
# 863                        Routing in Unit Disk Graphs
# 875                        The grounding for Continuum
# 894  A First Practical Fully Homomorphic Crypto-Pro...
# 910  My Reflections on the First Man vs. Machine No...
# 912                           Convexity in Tree Spaces
# 931  Evaluation of the Intel Xeon Phi 7120 and NVID...
# 939  Reorganizing topologies of Steiner trees to ac...
# 940  Eliminating Higher-Multiplicity Intersections,...
# 958  On the robust hardness of Gr\"obner basis comp...
# 964  Developing a High Performance Software Library...
#
#                                            description  \
# 8      Rotation distance between trees measures the...
# 9      Rotation distance between rooted binary tree...
# 17     We consider five different peer-to-peer file...
# 34     Objectives: Text categorization has been use...
# 41     Given two elliptic curves over a finite fiel...
# 43     In this paper, we study the complexity of co...
# 54     We give an algebraic quantifier elimination ...
# 57     We show that $m$ points and $n$ smooth algeb...
# 61     The aim of this book is to develop "from the...
# 67     We analyse the resilience of the quantum sea...
# 85     The construction of shortest feedback shift ...
# 101    Guttman presented a model-theoretic approach...
# 108    This paper gives an introduction to the prob...
# 113    We present a randomized iterative algorithm ...
# 114    Application Programming Interfaces (API) are...
# 120    We study the computational content of the Br...
# 123    Classical objects in computational geometry ...
# 128    Scientific computation is a discipline that ...
# 131    We study algorithms for the fast computation...
# 134    We prove that an automorphism of order 3 of ...
# 139    Let $\mathscr O$ be a set of $n$ disjoint ob...
# 140    Exponentiation makes the difference between ...
# 142    In this article, we devise a concise algorit...
# 152    The Voronoi diagram is a certain geometric d...
# 155    We construct a computable, computably catego...
# 158    The QR factorization and the SVD are two fun...
# 164    An integer $n$ is $(y,z)$-semismooth if $n=p...
# 172    Global Value Numbering(GVN) is a popular met...
# 174    Let $p\geq3$ be a prime and $e\geq2$ an inte...
# 190    In the Boundary Labeling problem, we are giv...
# ..                                                 ...
# 658    In exploratory data analysis, we are often i...
# 666    In this work we present a very simple and ef...
# 714    This letter considers waveform design of ort...
# 729    The Dubins Traveling Salesman Problem (DTSP)...
# 734    Computations with integro-differential opera...
# 743    Given n subspaces of a finite-dimensional ve...
# 749    Similarly to the modelling of entanglement i...
# 765    This article proposes a method to quantitati...
# 784    In a cascading power transmission outage, co...
# 789    In this work, an evolving Linked Quantum reg...
# 791    The Split algorithm is an essential building...
# 797    An $r$-gentiling is a dissection of a shape ...
# 818    Let $\psi_m$ be the smallest strong pseudopr...
# 819    Inclusion diagrams are introduced as an alte...
# 820    Numerical accuracy of floating point computa...
# 825    We study the $O_\beta$-hull of a planar poin...
# 841    We establish new bounds on the number of tan...
# 849    Many cryptographic protocols are designed to...
# 853    We prove that every bounded rational space c...
# 858    Approximate Spectral Clustering (ASC) is a p...
# 863    Let $S \subset \mathbb{R}^2$ be a set of $n$...
# 875    It is a ubiquitous opinion among mathematici...
# 894    Following a sequence of hardware designs for...
# 910    The first ever human vs. computer no-limit T...
# 912    We study the geometry of metrics and convexi...
# 931    To optimize the geometry of airfoils for a s...
# 939    We describe a technique to reorganize topolo...
# 940    We study conditions under which a finite sim...
# 958    The computation of Gr\"obner bases is an est...
# 964    Nowadays, the paradigm of parallel computing...
#
#                                                subject  \
# 8    Computer Science - Data Structures and Algorit...
# 9    Computer Science - Data Structures and Algorit...
# 17   Computer Science - Operating Systems ; Mathema...
# 34   Computer Science - Information Retrieval ; Sta...
# 41   Quantum Physics ; Computer Science - Computati...
# 43      Computer Science - Computational Complexity ;
# 54   Computer Science - Symbolic Computation ; Comp...
# 57   Mathematics - Combinatorics ; Computer Science...
# 61   Quantum Physics ; Computer Science - Informati...
# 67   Quantum Physics ; Computer Science - Computati...
# 85   Computer Science - Information Theory ; Comput...
# 101  Computer Science - Cryptography and Security ;...
# 108       Computer Science - Computational Geometry ;
# 113  Mathematics - Numerical Analysis ; Computer Sc...
# 114         Computer Science - Software Engineering ;
# 120  Mathematics - Logic ; Computer Science - Logic...
# 123  Computer Science - Computational Geometry ; Ma...
# 128  Computer Science - Programming Languages ; Com...
# 131  Computer Science - Symbolic Computation ; Comp...
# 134  Mathematics - Combinatorics ; Computer Science...
# 139  Computer Science - Data Structures and Algorit...
# 140  Computer Science - Computational Complexity ; ...
# 142  Computer Science - Data Structures and Algorit...
# 152  Computer Science - Computational Geometry ; Co...
# 155  Mathematics - Logic ; Computer Science - Logic...
# 158  Computer Science - Distributed, Parallel, and ...
# 164  Computer Science - Data Structures and Algorit...
# 172  Computer Science - Programming Languages ; Com...
# 174  Computer Science - Information Theory ; 11T71,...
# 190       Computer Science - Computational Geometry ;
# ..                                                 ...
# 658  Statistics - Methodology ; Computer Science - ...
# 666  Computer Science - Computational Engineering, ...
# 714  Electrical Engineering and Systems Science - S...
# 729  Mathematics - Optimization and Control ; Compu...
# 734  Computer Science - Symbolic Computation ; Math...
# 743  Computer Science - Data Structures and Algorit...
# 749    Computer Science - Logic in Computer Science ;
# 765  Physics - Physics and Society ; Computer Scien...
# 784  Physics - Physics and Society ; Computer Scien...
# 789  Computer Science - Neural and Evolutionary Com...
# 791  Computer Science - Data Structures and Algorit...
# 797  Computer Science - Computational Geometry ; Ma...
# 818  Mathematics - Number Theory ; Computer Science...
# 819  Computer Science - Logic in Computer Science ;...
# 820  Computer Science - Mathematical Software ; Com...
# 825  Computer Science - Computational Geometry ; 68...
# 841  Mathematics - Combinatorics ; Computer Science...
# 849    Computer Science - Cryptography and Security ;
# 853  Computer Science - Computational Geometry ; Co...
# 858         Computer Science - Discrete Mathematics ;
# 863  Computer Science - Computational Geometry ; Co...
# 875  Mathematics - Logic ; Computer Science - Logic...
# 894    Computer Science - Cryptography and Security ;
# 910  Computer Science - Computer Science and Game T...
# 912  Mathematics - Metric Geometry ; Computer Scien...
# 931  Computer Science - Distributed, Parallel, and ...
# 939  Computer Science - Data Structures and Algorit...
# 940  Mathematics - Geometric Topology ; Computer Sc...
# 958         Computer Science - Symbolic Computation ;
# 964  Computer Science - Distributed, Parallel, and ...
#
#                                                creator  \
# 8                Cleary, Sean ; John, Katherine St. ;
# 9                Cleary, Sean ; John, Katherine St. ;
# 17     Norros, Ilkka ; Reittu, Hannu ; Eirola, Timo ;
# 34   Kastrin, Andrej ; Peterlin, Borut ; Hristovski...
# 41   Childs, Andrew M. ; Jao, David ; Soukharev, Vl...
# 43   Chien, Steve ; Harsha, Prahladh ; Sinclair, Al...
# 54   Gao, Sicun ; Platzer, André ; Clarke, Edmund M...
# 57                                     Zahl, Joshua ;
# 61                                   Wilde, Mark M. ;
# 67   Gawron, Piotr ; Klamka, Jerzy ; Winiarczyk, Ry...
# 85                          Kuijper, M. ; Pinto, R. ;
# 101                               Ramsdell, John D. ;
# 108  Chalopin, Jérémie ; Das, Shantanu ; Disser, Ya...
# 113          Zouzias, Anastasios ; Freris, Nikolaos ;
# 114  Monperrus, Martin ; Eichberg, Michael ; Tekes,...
# 120  Brattka, Vasco ; Roux, Stéphane Le ; Miller, J...
# 123                                    Reem, Daniel ;
# 128                             Knepley, Matthew G. ;
# 131                           Dumas, Jean-Guillaume ;
# 134  Bouyuklieva, Stefka ; de la Cruz, Javier ; Wil...
# 139                                      Wang, Jack ;
# 140                                Levin, Leonid A. ;
# 142                                      Wang, Jack ;
# 152                                    Reem, Daniel ;
# 155               Miller, Russell ; Schoutens, Hans ;
# 158  Benson, Austin R. ; Gleich, David F. ; Demmel,...
# 164                 Bach, Eric ; Sorenson, Jonathan ;
# 172            Nabeezath, Saleena ; Paleri, Vineeth ;
# 174                             Wang, Lin ; Hu, Zhi ;
# 190  Kindermann, Philipp ; Niedermann, Benjamin ; R...
# ..                                                 ...
# 658  Reshef, David N. ; Reshef, Yakir A. ; Sabeti, ...
# 666  Gawryluk, Krzysztof ; Karpiuk, Tomasz ; Gajda,...
# 714                     Huang, Tianyao ; Zhao, Tong ;
# 729     Manyam, Satyanarayana ; Rathinam, Sivakumar ;
# 734  Bui, Van Chiên ; Duchamp, Gérard H. E. ; Ngô, ...
# 743      Jeong, Jisu ; Kim, Eun Jung ; Oum, Sang-il ;
# 749                                      Wang, Yong ;
# 765                Donovan, Brian ; Work, Daniel B. ;
# 784  Hines, Paul D. H. ; Dobson, Ian ; Rezaei, Pooy...
# 789                  Ullah, Sajid ; Wahid, Mussarat ;
# 791                                  Vidal, Thibaut ;
# 797                               Haverkort, Herman ;
# 818       Sorenson, Jonathan P. ; Webster, Jonathan ;
# 819  Skliar, Osvaldo ; Monge, Ricardo E. ; Gapper, ...
# 820  Denis, Christophe ; Castro, Pablo De Oliveira ...
# 825  Alegría-Galicia, Carlos ; Orden, David ; Seara...
# 841  Ellenberg, Jordan S. ; Solymosi, Jozsef ; Zahl...
# 849  Guttman, Joshua D. ; Liskov, Moses D. ; Ramsde...
# 853  Li, Zijia ; Schicho, Josef ; Schröcker, Hans-P...
# 858                   Kolev, Pavel ; Mehlhorn, Kurt ;
# 863  Kaplan, Haim ; Mulzer, Wolfgang ; Roditty, Lia...
# 875                       Ambroszkiewicz, Stanislaw ;
# 894                 Breuer, Peter ; Bowen, Jonathan ;
# 910                                  Ganzfried, Sam ;
# 912  Lin, Bo ; Sturmfels, Bernd ; Tang, Xiaoxian ; ...
# 931                                Einkemmer, Lukas ;
# 939              Grodet, Aymeric ; Tsuchiya, Takuya ;
# 940  Avvakumov, S. ; Mabillard, I. ; Skopenkov, A. ...
# 958                  Spencer, Gwen ; Rolnick, David ;
# 964                Oancea, Bogdan ; Andrei, Tudorel ;
#
#                                         combine_column  \
# 8    Rotation Distance is Fixed-Parameter Tractable...
# 9    A Linear-Time Approximation Algorithm for Rota...
# 17   On the stability of two-chunk file-sharing sys...
# 34   Chi-square-based scoring function for categori...
# 41   Constructing elliptic curve isogenies in quant...
# 43   Almost Settling the Hardness of Noncommutative...
# 54   Quantifier Elimination over Finite Fields Usin...
# 57   An improved bound on the number of point-surfa...
# 61   From Classical to Quantum Shannon Theory  The ...
# 67   Noise effects in the quantum search algorithm ...
# 85   An iterative algorithm for parametrization of ...
# 101  Deducing Security Goals From Shape Analysis Se...
# 108  Simple Agents Learn to Find Their Way: An Intr...
# 113  Randomized Extended Kaczmarz for Solving Least...
# 114  What Should Developers Be Aware Of? An Empiric...
# 120  Connected Choice and the Brouwer Fixed Point T...
# 123  On the computation of zone and double zone dia...
# 128  Programming Languages for Scientific Computing...
# 131  On Newton-Raphson iteration for multiplicative...
# 134  On the Automorphism Group of a Binary Self-dua...
# 139  Finding Efficient Region in The Plane with Lin...
# 140  Randomness and Non-determinism  Exponentiation...
# 142  A Simple Algorithm for Computing BOCP  In this...
# 152  The projector algorithm: a simple parallel alg...
# 155  Computably Categorical Fields via Fermat's Las...
# 158  Direct QR factorizations for tall-and-skinny m...
# 164  Approximately counting semismooth integers  An...
# 172  A Note on "A polynomial-time algorithm for glo...
# 174  Injectivity w.r.t. Distribution of Elements in...
# 190  Multi-Sided Boundary Labeling  In the Boundary...
# ..                                                 ...
# 658  An Empirical Study of Leading Measures of Depe...
# 666  Unified way for computing dynamics of Bose-Ein...
# 714  Low PMEPR OFDM radar waveform design using the...
# 729  On Tightly Bounding the Dubins Traveling Sales...
# 734  (Pure) transcendence bases in $\phi$-deformed ...
# 743  The "art of trellis decoding" is fixed-paramet...
# 749  Entanglement in Reversible Quantum Computing  ...
# 765  Using coarse GPS data to quantify city-scale t...
# 784  Cascading Power Outages Propagate Locally in a...
# 789  Topology Control of wireless sensor network us...
# 791  Technical Note: Split Algorithm in O(n) for th...
# 797  No acute tetrahedron is an 8-reptile  An $r$-g...
# 818  Strong Pseudoprimes to Twelve Prime Bases  Let...
# 819  Using Inclusion Diagrams as an Alternative to ...
# 820  Verificarlo: checking floating point accuracy ...
# 825  On the $O_\beta$-hull of a planar point set  W...
# 841  New bounds on curve tangencies and orthogonali...
# 849  Formal Support for Standardizing Protocols wit...
# 853  Kempe's Universality Theorem for Rational Spac...
# 858  Approximate Spectral Clustering: Efficiency an...
# 863  Routing in Unit Disk Graphs  Let $S \subset \m...
# 875  The grounding for Continuum  It is a ubiquitou...
# 894  A First Practical Fully Homomorphic Crypto-Pro...
# 910  My Reflections on the First Man vs. Machine No...
# 912  Convexity in Tree Spaces  We study the geometr...
# 931  Evaluation of the Intel Xeon Phi 7120 and NVID...
# 939  Reorganizing topologies of Steiner trees to ac...
# 940  Eliminating Higher-Multiplicity Intersections,...
# 958  On the robust hardness of Gr\"obner basis comp...
# 964  Developing a High Performance Software Library...
#
#                                        combine_cleaned  cuenta  cluster  \
# 8    rotation distance fix parameter tractable rota...      48        4
# 9    linear time approximation algorithm rotation d...      43        4
# 17   stability two chunk file share systems conside...      67        4
# 34   chi square base score function categorization ...     166        4
# 41   construct elliptic curve isogenies quantum sub...     104        4
# 43   almost settle hardness noncommutative determin...     145        4
# 54   quantifier elimination finite field use gr obn...      44        4
# 57   improve bind number point surface incidences t...     105        4
# 61   classical quantum shannon theory aim book deve...      72        4
# 67   noise effect quantum search algorithm computat...      42        4
# 85   iterative algorithm parametrization shortest l...      65        4
# 101  deduce security goals shape analysis sentence ...      48        4
# 108  simple agents learn find way introduction map ...     111        4
# 113  randomize extend kaczmarz solve least square p...      53        4
# 114  developers aware empirical study directives ap...      53        4
# 120  connect choice brouwer fix point theorem study...     145        4
# 123  computation zone double zone diagram classical...     146        4
# 128  program languages scientific compute scientifi...      60        4
# 131  newton raphson iteration multiplicative invers...      69        4
# 134  automorphism group binary self dual code prove...      55        4
# 139  find efficient region plane line segment let m...     129        4
# 140  randomness non determinism exponentiation make...      85        4
# 142  simple algorithm compute bocp article devise c...      47        4
# 152  projector algorithm simple parallel algorithm ...     111        4
# 155  computably categorical field via fermat last t...      32        4
# 158  direct qr factorizations tall skinny matrices ...     124        4
# 164  approximately count semismooth integers intege...      65        4
# 172  note polynomial time algorithm global value nu...      65        4
# 174  injectivity distribution elements compress seq...     118        4
# 190  multi side boundary label boundary label probl...     117        4
# ..                                                 ...     ...      ...
# 658  empirical study lead measure dependence explor...     168        4
# 666  unify way compute dynamics bose einstein conde...      75        4
# 714  low pmepr ofdm radar waveform design use itera...      89        4
# 729  tightly bound dubins travel salesman optimum d...      74        4
# 734  pure transcendence base phi deform shuffle bia...      81        4
# 743  art trellis decode fix parameter tractable giv...     167        4
# 749  entanglement reversible quantum compute simila...      28        4
# 765  use coarse gps data quantify city scale transp...     125        4
# 784  cascade power outages propagate locally influe...     130        4
# 789  topology control wireless sensor network use q...      79        4
# 791  technical note split algorithm capacitate vehi...     119        4
# 797  acute tetrahedron reptile gentiling dissection...      32        4
# 818  strong pseudoprimes twelve prime base let psi ...      38        4
# 819  use inclusion diagram alternative venn diagram...      49        4
# 820  verificarlo check float point accuracy monte c...     103        4
# 825  beta hull planar point set study beta hull pla...      60        4
# 841  new bound curve tangencies orthogonalities est...     111        4
# 849  formal support standardize protocols state man...      78        4
# 853  kempe universality theorem rational space curv...      43        4
# 858  approximate spectral cluster efficiency guaran...     107        4
# 863  rout unit disk graph let subset mathbb set sit...     129        4
# 875  ground continuum ubiquitous opinion among math...     129        4
# 894  first practical fully homomorphic crypto proce...     113        4
# 910  reflections first man vs machine limit texas h...      37        4
# 912  convexity tree space study geometry metrics co...      53        4
# 931  evaluation intel xeon phi nvidia accelerators ...     109        4
# 939  reorganize topologies steiner tree accelerate ...     123        4
# 940  eliminate higher multiplicity intersections ii...     126        4
# 958  robust hardness gr obner basis computation com...     102        4
# 964  develop high performance software library mpi ...     138        4
#
#           name_file
# 8     0903.0197.txt
# 9     0903.0199.txt
# 17    0910.5577.txt
# 34    1006.1029.txt
# 41    1012.4019.txt
# 43    1101.1169.txt
# 54    1104.0746.txt
# 57    1104.4987.txt
# 61    1106.1445.txt
# 67    1108.1915.txt
# 85    1201.5921.txt
# 101   1204.0480.txt
# 108   1204.3850.txt
# 113   1205.5770.txt
# 114   1205.6363.txt
# 120   1206.4809.txt
# 123   1208.3124.txt
# 128   1209.1711.txt
# 131   1209.6626.txt
# 134   1210.2540.txt
# 139   1210.7638.txt
# 140   1211.0071.txt
# 142   1211.0729.txt
# 152   1212.1095.txt
# 155   1212.6751.txt
# 158   1301.1071.txt
# 164   1301.5293.txt
# 172   1302.6325.txt
# 174   1303.0926.txt
# 190   1305.0750.txt
# ..              ...
# 658  1505.02214.txt
# 666  1505.04036.txt
# 714  1506.06055.txt
# 729  1506.08752.txt
# 734  1507.01089.txt
# 743  1507.02184.txt
# 749  1507.03344.txt
# 765  1507.06011.txt
# 784  1508.01775.txt
# 789  1508.02521.txt
# 791  1508.02759.txt
# 797  1508.03773.txt
# 818  1509.00864.txt
# 819  1509.00926.txt
# 820  1509.01347.txt
# 825  1509.02601.txt
# 841  1509.05821.txt
# 849  1509.07552.txt
# 853  1509.08690.txt
# 858  1509.09188.txt
# 863  1510.01072.txt
# 875  1510.02787.txt
# 894  1510.05278.txt
# 910  1510.08578.txt
# 912  1510.08797.txt
# 931  1511.02166.txt
# 939  1511.03407.txt
# 940  1511.03501.txt
# 958  1511.06436.txt
# 964  1511.07174.txt
#
# [115 rows x 10 columns]

# %% [markdown]
# ## Grupos de documentos

# %%
gruposdocsA = pd.read_csv('clustertable_articles.csv')
gruposdocsA['name_file'] = gruposdocsA['identifier'].apply(lambda x: x.split('/')[-1]+'.txt')
gruposdocsA.rename(columns = {'prediction':'clusterA'}, inplace = True)
gruposdocsA_merge = gruposdocsA[['name_file','clusterA']].copy()
del gruposdocsA

# %%
ldaA = pd.read_csv('ldaresults_articles.csv')
ldaA['name_file'] = ldaA['identifier'].apply(lambda x: x.split('/')[-1]+'.txt')
ldaA_merge = ldaA[['name_file','mainTopic']].copy()
del ldaA

# %%
totalDocs = gruposbydoc.merge(gruposdocsA_merge, how = 'outer',on = 'name_file')
totalDocs = totalDocs.merge(ldaA_merge, how = 'outer',on = 'name_file')
totalDocs
# Out:
#                           identifier  \
# 0     http://arxiv.org/abs/0704.3504
# 1     http://arxiv.org/abs/0706.1402
# 2     http://arxiv.org/abs/0710.0736
# 3     http://arxiv.org/abs/0803.2570
# 4     http://arxiv.org/abs/0808.0084
# 5     http://arxiv.org/abs/0811.1254
# 6     http://arxiv.org/abs/0811.2853
# 7     http://arxiv.org/abs/0812.2709
# 8     http://arxiv.org/abs/0903.0197
# 9     http://arxiv.org/abs/0903.0199
# 10    http://arxiv.org/abs/0903.1291
# 11    http://arxiv.org/abs/0903.2923
# 12    http://arxiv.org/abs/0903.4386
# 13    http://arxiv.org/abs/0904.2051
# 14    http://arxiv.org/abs/0907.3220
# 15    http://arxiv.org/abs/0907.3965
# 16    http://arxiv.org/abs/0910.2912
# 17    http://arxiv.org/abs/0910.5577
# 18    http://arxiv.org/abs/0911.1507
# 19    http://arxiv.org/abs/0911.1509
# 20    http://arxiv.org/abs/0911.1544
# 21    http://arxiv.org/abs/0911.1546
# 22    http://arxiv.org/abs/0911.2538
# 23    http://arxiv.org/abs/0911.2746
# 24    http://arxiv.org/abs/0911.5153
# 25    http://arxiv.org/abs/1001.1435
# 26    http://arxiv.org/abs/1001.3780
# 27    http://arxiv.org/abs/1002.0747
# 28    http://arxiv.org/abs/1003.1628
# 29    http://arxiv.org/abs/1004.0208
# ..                               ...
# 950  http://arxiv.org/abs/1511.05546
# 951  http://arxiv.org/abs/1511.05635
# 952  http://arxiv.org/abs/1511.05646
# 953  http://arxiv.org/abs/1511.05710
# 954  http://arxiv.org/abs/1511.06030
# 955  http://arxiv.org/abs/1511.06033
# 956  http://arxiv.org/abs/1511.06324
# 957  http://arxiv.org/abs/1511.06382
# 958  http://arxiv.org/abs/1511.06436
# 959  http://arxiv.org/abs/1511.06444
# 960  http://arxiv.org/abs/1511.06489
# 961  http://arxiv.org/abs/1511.06653
# 962  http://arxiv.org/abs/1511.06860
# 963  http://arxiv.org/abs/1511.06971
# 964  http://arxiv.org/abs/1511.07174
# 965  http://arxiv.org/abs/1511.07212
# 966  http://arxiv.org/abs/1511.07860
# 967  http://arxiv.org/abs/1511.08152
# 968  http://arxiv.org/abs/1511.08189
# 969  http://arxiv.org/abs/1511.08280
# 970  http://arxiv.org/abs/1511.08416
# 971  http://arxiv.org/abs/1511.08575
# 972  http://arxiv.org/abs/1511.08585
# 973  http://arxiv.org/abs/1511.08861
# 974  http://arxiv.org/abs/1511.08887
# 975  http://arxiv.org/abs/1511.09156
# 976  http://arxiv.org/abs/1511.09259
# 977  http://arxiv.org/abs/1511.09324
# 978  http://arxiv.org/abs/1512.00135
# 979  http://arxiv.org/abs/1512.00327
#
#                                                  title  \
# 0    Smooth R\'enyi Entropy of Ergodic Quantum Info...
# 1    Analyzing Design Process and Experiments on th...
# 2    Colour image segmentation by the vector-valued...
# 3    Unequal Error Protection: An Information Theor...
# 4    On the hitting times of quantum versus random ...
# 5            Coding Theory and Algebraic Combinatorics
# 6      Generating Random Networks Without Short Cycles
# 7      Variations on a theme by Schalkwijk and Kailath
# 8       Rotation Distance is Fixed-Parameter Tractable
# 9    A Linear-Time Approximation Algorithm for Rota...
# 10       The quantum query complexity of certification
# 11   On uncertainty principles in the finite dimens...
# 12   Error-and-Erasure Decoding for Block Codes wit...
# 13    Joint-sparse recovery from multiple measurements
# 14   Inter Genre Similarity Modelling For Automatic...
# 15                                       P != NP Proof
# 16   Universally Composable Quantum Multi-Party Com...
# 17   On the stability of two-chunk file-sharing sys...
# 18                           MAC Layer Hurdles in BSNs
# 19   On the Development of Low Power MAC Protocol f...
# 20   Towards Power Efficient MAC Protocol for In-Bo...
# 21   A Study of Implanted and Wearable Body Sensor ...
# 22   Euclidean versus hyperbolic congestion in idea...
# 23   Model Selection: Two Fundamental Measures of C...
# 24               Self-Reference Ultra-Wideband Systems
# 25   JBotSim, a Tool for Fast Prototyping of Distri...
# 26   Combinatorial Bounds and Characterizations of ...
# 27   Efficient Bayesian Learning in Social Networks...
# 28               Having Fun with Lambert W(x) Function
# 29   Delay-rate tradeoff in ergodic interference al...
# ..                                                 ...
# 950  Complexity and Approximability of Parameterize...
# 951                Competitive Multi-scale Convolution
# 952       The Invisible Hand of Dynamic Market Pricing
# 953   Complex-Valued Gaussian Processes for Regression
# 954  BIRDNEST: Bayesian Inference for Ratings-Fraud...
# 955  EigenRec: Generalizing PureSVD for Effective a...
# 956  Global Convergence of ADMM in Nonconvex Nonsmo...
# 957  Iterative Refinement of the Approximate Poster...
# 958  On the robust hardness of Gr\"obner basis comp...
# 959  Universal halting times in optimization and ma...
# 960  A Simple Hierarchical Pooling Data Structure f...
# 961  Recurrent Semi-supervised Classification and C...
# 962  Convex Sparse Spectral Clustering: Single-view...
# 963  A General Framework for the Design and Analysi...
# 964  Developing a High Performance Software Library...
# 965   Face Alignment Across Large Poses: A 3D Solution
# 966  Super-Linear Gate and Super-Quadratic Wire Low...
# 967                    Max-Cut under Graph Constraints
# 968                 Graph Isomorphism and Circuit Size
# 969  Welfare of Sequential Allocation Mechanisms fo...
# 970       Who Can Win a Single-Elimination Tournament?
# 971  A Modified Multiple OLS (m$^2$OLS) Algorithm f...
# 972  Real-Time Residential-Side Joint Energy Storag...
# 973  Loss Functions for Neural Networks for Image P...
# 974  On the Degrees of Freedom of the Symmetric Mul...
# 975  Constant-approximation algorithms for highly c...
# 976  The Alternating Stock Size Problem and the Gas...
# 977  Isomorphisms considered as equalities: Project...
# 978  Entropies of weighted sums in cyclic groups an...
# 979     Technical Privacy Metrics: a Systematic Survey
#
#                                            description  \
# 0      We prove that the average smooth Renyi entro...
# 1      In the field of tutoring systems, investigat...
# 2      We propose a new method for the numerical so...
# 3      An information theoretic framework for unequ...
# 4      In this paper we define new Monte Carlo type...
# 5      This chapter introduces and elaborates on th...
# 6      Random graph generation is an important tool...
# 7      Schalkwijk and Kailath (1966) developed a cl...
# 8      Rotation distance between trees measures the...
# 9      Rotation distance between rooted binary tree...
# 10     We study the quantum query complexity of fin...
# 11     The aim of this paper is to prove an uncerta...
# 12     Inner and outer bounds are derived on the op...
# 13     The joint-sparse recovery problem aims to re...
# 14     Music genre classification is an essential t...
# 15     This paper demonstrates that P \not= NP. The...
# 16     The Universal Composability model (UC) by Ca...
# 17     We consider five different peer-to-peer file...
# 18     The last few decades have seen considerable ...
# 19     Current advances in wireless communication, ...
# 20     This paper presents an empirical discussion ...
# 21     Recent advances in intelligent sensors, micr...
# 22     This paper proposes a mathematical justifica...
# 23     The problem of model selection arises in a n...
# 24     Towards employing low complexity transceiver...
# 25     JBotSim is a java library that offers basic ...
# 26     We present several generalizations of result...
# 27     We consider a group of Bayesian agents who t...
# 28     This short note presents the Lambert W(x) fu...
# 29     Ergodic interference alignment, as introduce...
# ..                                                 ...
# 950    We study the optimization version of constra...
# 951    In this paper, we introduce a new deep convo...
# 952    Walrasian prices, if they exist, have the pr...
# 953    In this paper we propose a novel Bayesian so...
# 954    Review fraud is a pervasive problem in onlin...
# 955    We introduce EigenRec; a versatile and effic...
# 956    In this paper, we analyze the convergence of...
# 957    Variational methods that rely on a recogniti...
# 958    The computation of Gr\"obner bases is an est...
# 959    The authors present empirical distributions ...
# 960    We propose a data structure obtained by hier...
# 961    We explore recurrent encoder multi-decoder n...
# 962    Spectral Clustering (SC) is one of the most ...
# 963    Complexity of linear finite-impulse-response...
# 964    Nowadays, the paradigm of parallel computing...
# 965    Face alignment, which fits a face model to a...
# 966    In order to formally understand the power of...
# 967    An instance of the graph-constrained max-cut...
# 968    It is well-known [KST93] that the complexity...
# 969    Sequential allocation is a simple and attrac...
# 970    A single-elimination (SE) tournament is a po...
# 971    Orthogonal least square (OLS) is an importan...
# 972    We consider joint energy storage management ...
# 973    Neural networks are becoming central in seve...
# 974    In this paper, we study the degrees of freed...
# 975    Given an undirected graph on a node set $V$ ...
# 976    Given a set S of integers whose sum is zero,...
# 977    We propose an implementation of lambda+, a r...
# 978    In this note, the following basic question i...
# 979    The goal of privacy metrics is to measure th...
#
#                                                subject  \
# 0    Quantum Physics ; Computer Science - Informati...
# 1    Computer Science - Computers and Society ; Com...
# 2    Computer Science - Computer Vision and Pattern...
# 3    Computer Science - Information Theory ; Comput...
# 4    Quantum Physics ; Computer Science - Data Stru...
# 5    Mathematics - Combinatorics ; Computer Science...
# 6    Computer Science - Data Structures and Algorit...
# 7             Computer Science - Information Theory ;
# 8    Computer Science - Data Structures and Algorit...
# 9    Computer Science - Data Structures and Algorit...
# 10   Quantum Physics ; Computer Science - Computati...
# 11   Mathematics - Classical Analysis and ODEs ; Co...
# 12            Computer Science - Information Theory ;
# 13            Computer Science - Information Theory ;
# 14   Computer Science - Sound ; Computer Science - ...
# 15   Computer Science - Computational Complexity ; ...
# 16   Quantum Physics ; Computer Science - Cryptogra...
# 17   Computer Science - Operating Systems ; Mathema...
# 18   Computer Science - Networking and Internet Arc...
# 19   Computer Science - Networking and Internet Arc...
# 20   Computer Science - Networking and Internet Arc...
# 21   Computer Science - Networking and Internet Arc...
# 22   Computer Science - Networking and Internet Arc...
# 23   Computer Science - Information Theory ; Mathem...
# 24   Computer Science - Networking and Internet Arc...
# 25   Computer Science - Mathematical Software ; Com...
# 26   Computer Science - Cryptography and Security ;...
# 27   Statistics - Applications ; Computer Science -...
# 28   Computer Science - Mathematical Software ; Com...
# 29   Computer Science - Information Theory ; Mathem...
# ..                                                 ...
# 950  Computer Science - Computational Complexity ; ...
# 951  Computer Science - Computer Vision and Pattern...
# 952  Computer Science - Computer Science and Game T...
# 953             Computer Science - Machine Learning ;
# 954  Computer Science - Artificial Intelligence ; C...
# 955  Computer Science - Information Retrieval ; Com...
# 956  Mathematics - Optimization and Control ; Compu...
# 957  Computer Science - Machine Learning ; Statisti...
# 958         Computer Science - Symbolic Computation ;
# 959  Computer Science - Machine Learning ; Mathemat...
# 960  Computer Science - Computer Vision and Pattern...
# 961  Computer Science - Computer Vision and Pattern...
# 962  Computer Science - Computer Vision and Pattern...
# 963           Computer Science - Information Theory ;
# 964  Computer Science - Distributed, Parallel, and ...
# 965  Computer Science - Computer Vision and Pattern...
# 966  Computer Science - Computational Complexity ; ...
# 967  Computer Science - Data Structures and Algorit...
# 968     Computer Science - Computational Complexity ;
# 969  Computer Science - Artificial Intelligence ; C...
# 970  Computer Science - Computer Science and Game T...
# 971  Computer Science - Information Theory ; Statis...
# 972          Computer Science - Systems and Control ;
# 973  Computer Science - Computer Vision and Pattern...
# 974           Computer Science - Information Theory ;
# 975  Computer Science - Data Structures and Algorit...
# 976  Computer Science - Data Structures and Algorit...
# 977  Computer Science - Logic in Computer Science ;...
# 978           Computer Science - Information Theory ;
# 979  Computer Science - Cryptography and Security ;...
#
#                                                creator  \
# 0    Schoenmakers, Berry ; Tjoelker, Jilles ; Tuyls...
# 1           Brust, Matthias R. ; Rothkugel, Steffen ;
# 2                 Kay, David A ; Tomasi, Alessandro ;
# 3    Borade, Shashi ; Nakiboglu, Baris ; Zheng, Liz...
# 4    Magniez, Frederic ; Nayak, Ashwin ; Richter, P...
# 5                                    Huber, Michael ;
# 6    Bayati, Mohsen ; Montanari, Andrea ; Saberi, A...
# 7            Gallager, Robert G. ; Nakiboglu, Baris ;
# 8                Cleary, Sean ; John, Katherine St. ;
# 9                Cleary, Sean ; John, Katherine St. ;
# 10   Ambainis, Andris ; Childs, Andrew M. ; Gall, F...
# 11            Ghobber, Saifallah ; Jaming, Philippe ;
# 12                Nakiboglu, Baris ; Zheng, Lizhong ;
# 13    Berg, Ewout van den ; Friedlander, Michael P. ;
# 14                       Bagci, Ulas ; Erzin, Engin ;
# 15                              Barbosa, André Luiz ;
# 16                                 Unruh, Dominique ;
# 17     Norros, Ilkka ; Reittu, Hannu ; Eirola, Timo ;
# 18   Ullah, Sana ; Khan, Pervez ; Choi, Young-Woo ;...
# 19     Ullah, Sana ; Khan, Pervez ; Kwak, Kyung Sup ;
# 20        Ullah, Sana ; An, Xizhi ; Kwak, Kyung Sup ;
# 21   Ullah, Sana ; Higgins, Henry ; Siddiqui, M. Ar...
# 22   Jonckheere, Edmond ; Lou, Mingji ; Bonahon, Fr...
# 23   Bajwa, Waheed U. ; Calderbank, Robert ; Jafarp...
# 24                          Lioumpas, Athanasios S. ;
# 25                                Casteigts, Arnaud ;
# 26                                   Huber, Michael ;
# 27    Mossel, Elchanan ; Olsman, Noah ; Tamuz, Omer ;
# 28                                   Veberic, Darko ;
# 29   Johnson, Oliver ; Aldridge, Matthew ; Piechock...
# ..                                                 ...
# 950  Dell, Holger ; Kim, Eun Jung ; Lampis, Michael...
# 951                Liao, Zhibin ; Carneiro, Gustavo ;
# 952  Cohen-Addad, Vincent ; Eden, Alon ; Feldman, M...
# 953  Boloix-Tortosa, Rafael ; Arias-de-Reyna, Eva ;...
# 954  Hooi, Bryan ; Shah, Neil ; Beutel, Alex ; Gunn...
# 955  Nikolakopoulos, Athanasios N. ; Kalantzis, Vas...
# 956           Wang, Yu ; Yin, Wotao ; Zeng, Jinshan ;
# 957  Hjelm, R Devon ; Cho, Kyunghyun ; Chung, Junyo...
# 958                  Spencer, Gwen ; Rolnick, David ;
# 959   Sagun, Levent ; Trogdon, Thomas ; LeCun, Yann ;
# 960  Fei, Xiaohan ; Tsotsos, Konstantine ; Soatto, ...
# 961  Harvey, Félix G. ; Roy, Julien ; Kanaa, David ...
# 962      Lu, Canyi ; Yan, Shuicheng ; Lin, Zhouchen ;
# 963  Al-Abbasi, Abubakr O. ; Hamila, Ridha ; Bajwa,...
# 964                Oancea, Bogdan ; Andrei, Tudorel ;
# 965  Zhu, Xiangyu ; Lei, Zhen ; Liu, Xiaoming ; Shi...
# 966                Kane, Daniel M. ; Williams, Ryan ;
# 967  Lee, Jon ; Nagarajan, Viswanath ; Shen, Xiangk...
# 968  Allender, Eric ; Grochow, Joshua A. ; van Melk...
# 969  Aziz, Haris ; Kalinowski, Thomas ; Walsh, Toby...
# 970  Kim, Michael P. ; Suksompong, Warut ; Williams...
# 971  Mukhopadhyay, Samrat ; Satpathi, Siddhartha ; ...
# 972                          Li, Tianyi ; Dong, Min ;
# 973  Zhao, Hang ; Gallo, Orazio ; Frosio, Iuri ; Ka...
# 974  Ding, Tian ; Yuan, Xiaojun ; Liew, Soung Chang ;
# 975                                Fukunaga, Takuro ;
# 976  Newman, Alantha ; Röglin, Heiko ; Seif, Johann...
# 977  Díaz-Caro, Alejandro ; López, Pablo E. Martíne...
# 978  Abbe, Emmanuel ; Li, Jiange ; Madiman, Mokshay ;
# 979                 Wagner, Isabel ; Eckhoff, David ;
#
#                                         combine_column  \
# 0    Smooth R\'enyi Entropy of Ergodic Quantum Info...
# 1    Analyzing Design Process and Experiments on th...
# 2    Colour image segmentation by the vector-valued...
# 3    Unequal Error Protection: An Information Theor...
# 4    On the hitting times of quantum versus random ...
# 5    Coding Theory and Algebraic Combinatorics  Thi...
# 6    Generating Random Networks Without Short Cycle...
# 7    Variations on a theme by Schalkwijk and Kailat...
# 8    Rotation Distance is Fixed-Parameter Tractable...
# 9    A Linear-Time Approximation Algorithm for Rota...
# 10   The quantum query complexity of certification ...
# 11   On uncertainty principles in the finite dimens...
# 12   Error-and-Erasure Decoding for Block Codes wit...
# 13   Joint-sparse recovery from multiple measuremen...
# 14   Inter Genre Similarity Modelling For Automatic...
# 15   P != NP Proof  This paper demonstrates that P ...
# 16   Universally Composable Quantum Multi-Party Com...
# 17   On the stability of two-chunk file-sharing sys...
# 18   MAC Layer Hurdles in BSNs  The last few decade...
# 19   On the Development of Low Power MAC Protocol f...
# 20   Towards Power Efficient MAC Protocol for In-Bo...
# 21   A Study of Implanted and Wearable Body Sensor ...
# 22   Euclidean versus hyperbolic congestion in idea...
# 23   Model Selection: Two Fundamental Measures of C...
# 24   Self-Reference Ultra-Wideband Systems  Towards...
# 25   JBotSim, a Tool for Fast Prototyping of Distri...
# 26   Combinatorial Bounds and Characterizations of ...
# 27   Efficient Bayesian Learning in Social Networks...
# 28   Having Fun with Lambert W(x) Function  This sh...
# 29   Delay-rate tradeoff in ergodic interference al...
# ..                                                 ...
# 950  Complexity and Approximability of Parameterize...
# 951  Competitive Multi-scale Convolution  In this p...
# 952  The Invisible Hand of Dynamic Market Pricing  ...
# 953  Complex-Valued Gaussian Processes for Regressi...
# 954  BIRDNEST: Bayesian Inference for Ratings-Fraud...
# 955  EigenRec: Generalizing PureSVD for Effective a...
# 956  Global Convergence of ADMM in Nonconvex Nonsmo...
# 957  Iterative Refinement of the Approximate Poster...
# 958  On the robust hardness of Gr\"obner basis comp...
# 959  Universal halting times in optimization and ma...
# 960  A Simple Hierarchical Pooling Data Structure f...
# 961  Recurrent Semi-supervised Classification and C...
# 962  Convex Sparse Spectral Clustering: Single-view...
# 963  A General Framework for the Design and Analysi...
# 964  Developing a High Performance Software Library...
# 965  Face Alignment Across Large Poses: A 3D Soluti...
# 966  Super-Linear Gate and Super-Quadratic Wire Low...
# 967  Max-Cut under Graph Constraints  An instance o...
# 968  Graph Isomorphism and Circuit Size  It is well...
# 969  Welfare of Sequential Allocation Mechanisms fo...
# 970  Who Can Win a Single-Elimination Tournament?  ...
# 971  A Modified Multiple OLS (m$^2$OLS) Algorithm f...
# 972  Real-Time Residential-Side Joint Energy Storag...
# 973  Loss Functions for Neural Networks for Image P...
# 974  On the Degrees of Freedom of the Symmetric Mul...
# 975  Constant-approximation algorithms for highly c...
# 976  The Alternating Stock Size Problem and the Gas...
# 977  Isomorphisms considered as equalities: Project...
# 978  Entropies of weighted sums in cyclic groups an...
# 979  Technical Privacy Metrics: a Systematic Survey...
#
#                                        combine_cleaned  cuenta  cluster  \
# 0    smooth enyi entropy ergodic quantum informatio...      34       11
# 1    analyze design process experiment anita generi...     100       10
# 2    colour image segmentation vector value allen c...      69       11
# 3    unequal error protection information theoretic...      75        5
# 4    hit time quantum versus random walk paper defi...     120       11
# 5    cod theory algebraic combinatorics chapter int...      62        5
# 6    generate random network without short cycle ra...     107        3
# 7    variations theme schalkwijk kailath schalkwijk...      99        5
# 8    rotation distance fix parameter tractable rota...      48        4
# 9    linear time approximation algorithm rotation d...      43        4
# 10   quantum query complexity certification study q...      47        1
# 11   uncertainty principles finite dimensional set ...      37        7
# 12   error erasure decode block cod feedback inner ...      97        5
# 13   joint sparse recovery multiple measurements jo...      90        9
# 14   inter genre similarity model automatic music g...      91       11
# 15   np proof paper demonstrate np way generalize t...      85        8
# 16   universally composable quantum multi party com...      64        2
# 17   stability two chunk file share systems conside...      67        4
# 18   mac layer hurdle bsns last decades see conside...     103        2
# 19   development low power mac protocol wbans curre...      80        2
# 20   towards power efficient mac protocol body body...      76        2
# 21   study implant wearable body sensor network rec...      96        2
# 22   euclidean versus hyperbolic congestion idealiz...     115        6
# 23   model selection two fundamental measure cohere...     145        9
# 24   self reference ultra wideband systems towards ...      94       12
# 25   jbotsim tool fast prototyping distribute algor...      67        6
# 26   combinatorial bound characterizations split au...      52        5
# 27   efficient bayesian learn social network gaussi...     108        6
# 28   fun lambert function short note present lamber...      32       11
# 29   delay rate tradeoff ergodic interference align...     103       12
# ..                                                 ...     ...      ...
# 950  complexity approximability parameterized max c...      91        1
# 951  competitive multi scale convolution paper intr...     101        2
# 952  invisible hand dynamic market price walrasian ...      98        0
# 953  complex value gaussian process regression pape...     126       11
# 954  birdnest bayesian inference rat fraud detectio...     126       11
# 955  eigenrec generalize puresvd effective efficien...     109        9
# 956  global convergence admm nonconvex nonsmooth op...     162        7
# 957  iterative refinement approximate posterior dir...      81        6
# 958  robust hardness gr obner basis computation com...     102        4
# 959  universal halt time optimization machine learn...      96        6
# 960  simple hierarchical pool data structure loop c...      43       11
# 961  recurrent semi supervise classification constr...     108        6
# 962  convex sparse spectral cluster single view mul...     115        9
# 963  general framework design analysis sparse fir l...      92        9
# 964  develop high performance software library mpi ...     138        4
# 965  face alignment across large pose solution face...     127       11
# 966  super linear gate super quadratic wire lower b...     171        1
# 967  max cut graph constraints instance graph const...      98        3
# 968  graph isomorphism circuit size well know kst c...      41        3
# 969  welfare sequential allocation mechanisms indiv...      56        0
# 970  win single elimination tournament single elimi...     117        8
# 971  modify multiple ols ols algorithm signal recov...     119        9
# 972  real time residential side joint energy storag...     152       11
# 973  loss function neural network image process neu...      77        6
# 974  degrees freedom symmetric multi relay mimo cha...     145        9
# 975  constant approximation algorithms highly conne...     104        1
# 976  alternate stock size problem gasoline puzzle g...     128        7
# 977  isomorphisms consider equalities project funct...      75        8
# 978  entropies weight sum cyclic group application ...      77        5
# 979  technical privacy metrics systematic survey go...     111       10
#
#           name_file  clusterA  mainTopic
# 0     0704.3504.txt         1         10
# 1     0706.1402.txt         1          6
# 2     0710.0736.txt         1          1
# 3     0803.2570.txt         1         19
# 4     0808.0084.txt         1          8
# 5     0811.1254.txt         1         17
# 6     0811.2853.txt         1         16
# 7     0812.2709.txt         1         10
# 8     0903.0197.txt         1         17
# 9     0903.0199.txt         1         17
# 10    0903.1291.txt         1         15
# 11    0903.2923.txt         1          6
# 12    0903.4386.txt         1         19
# 13    0904.2051.txt         1          3
# 14    0907.3220.txt         1          8
# 15    0907.3965.txt         1          4
# 16    0910.2912.txt         1         19
# 17    0910.5577.txt         1         19
# 18    0911.1507.txt         0         17
# 19    0911.1509.txt         1         17
# 20    0911.1544.txt         1         17
# 21    0911.1546.txt         0         17
# 22    0911.2538.txt         1          5
# 23    0911.2746.txt         1          0
# 24    0911.5153.txt         1          4
# 25    1001.1435.txt         1          1
# 26    1001.3780.txt         1          1
# 27    1002.0747.txt         1          7
# 28    1003.1628.txt         1         12
# 29    1004.0208.txt         1          0
# ..              ...       ...        ...
# 950  1511.05546.txt         1          1
# 951  1511.05635.txt         7          9
# 952  1511.05646.txt         1         16
# 953  1511.05710.txt         1          0
# 954  1511.06030.txt         1         10
# 955  1511.06033.txt         1          5
# 956  1511.06324.txt         1         11
# 957  1511.06382.txt         1         18
# 958  1511.06436.txt         1          3
# 959  1511.06444.txt         1          2
# 960  1511.06489.txt         1         13
# 961  1511.06653.txt         1         13
# 962  1511.06860.txt         1          7
# 963  1511.06971.txt         1          3
# 964  1511.07174.txt         1         19
# 965  1511.07212.txt         1         12
# 966  1511.07860.txt         1         13
# 967  1511.08152.txt         1         12
# 968  1511.08189.txt         1          2
# 969  1511.08280.txt         1         16
# 970  1511.08416.txt         1         14
# 971  1511.08575.txt         1          2
# 972  1511.08585.txt         4          6
# 973  1511.08861.txt         1         13
# 974  1511.08887.txt         1          0
# 975  1511.09156.txt         1         18
# 976  1511.09259.txt         1          0
# 977  1511.09324.txt         1         14
# 978  1512.00135.txt         1          1
# 979  1512.00327.txt         1         11
#
# [980 rows x 12 columns]

# %%
totalDocs.to_csv('resultados3entrega.csv', index = False, decimal = '.')

# %% [markdown]
# ## Cuál documento quiere explorar más?
# Decir el ranking

# %%
documento = 0

# %%
cluster = totalDocs[totalDocs['name_file']==resultados['NombreArchivo'].iloc[documento]]['cluster'].values[0]
topic = totalDocs[totalDocs['name_file']==resultados['NombreArchivo'].iloc[documento]]['mainTopic'].values[0]

# %% [markdown]
# # Documentos que hacen parte del mismo clúster y al mismo tópico

# %%
totalDocs['File_Name'] = totalDocs.apply(lambda x: x['name_file']+ '-' + x['title'], axis = 1)

# %%
totalDocs[(totalDocs['cluster']==cluster)&(totalDocs['mainTopic']==topic)]['File_Name'].values
# Out:
# array(['1409.8580.txt-Interference Functionals in Poisson Networks',
#        '1412.4171.txt-Dynamics of Information Diffusion and Social Sensing',
#        '1502.04382.txt-Temporal Network Optimization Subject to Connectivity Constraints',
#        '1510.04249.txt-Random Irregular Block-hierarchical Networks: Algorithms for Computation   of Main Properties'],
#       dtype=object)

# %% [markdown]
# # Documentos que hacen parte del mismo clúster

# %%
totalDocs[(totalDocs['cluster']==cluster)]['File_Name'].values
# Out:
# array(['0911.2538.txt-Euclidean versus hyperbolic congestion in idealized versus experimental   networks',
#        '1001.1435.txt-JBotSim, a Tool for Fast Prototyping of Distributed Algorithms in   Dynamic Networks',
#        '1002.0747.txt-Efficient Bayesian Learning in Social Networks with Gaussian Estimators',
#        '1005.2894.txt-Optimal Gradient Clock Synchronization in Dynamic Networks',
#        '1111.3048.txt-On a Connection Between Small Set Expansions and Modularity Clustering   in Social Networks',
#        '1204.1160.txt-Opinion formation in time-varying social networks: The case of the   naming game',
#        '1209.5527.txt-Strategic Learning and the Topology of Social Networks',
#        '1210.7341.txt-Subset Codes for Packet Networks',
#        '1301.2959.txt-New elements for a network (including brain) general theory during   learning period',
#        '1301.3605.txt-Feature Learning in Deep Neural Networks - Studies on Speech Recognition   Tasks',
#        '1301.5522.txt-On Gaussian Half-Duplex Relay Networks',
#        '1303.5613.txt-Network Detection Theory and Performance',
#        '1304.2503.txt-Simulating the Smart Grid',
#        '1309.5568.txt-Integrating Communications and Merging Messaging via the eXtensible   Messaging and Presence Protocol',
#        '1310.1250.txt-Learning ambiguous functions by neural networks',
#        '1310.3389.txt-Spectra of random networks in the weak clustering regime',
#        '1312.1664.txt-Simplicial Homology for Future Cellular Networks',
#        '1312.3748.txt-On Eavesdropper-Tolerance Capability of Two-Hop Wireless Networks',
#        '1401.1333.txt-Time series forecasting using neural networks',
#        '1402.2760.txt-Rendezvous in Networks in Spite of Delay Faults',
#        '1402.6787.txt-Learning multifractal structure in large networks',
#        '1403.5543.txt-Disaster Recovery in Wireless Networks: A Homology-Based Algorithm',
#        '1406.2587.txt-Structural Sparsity of Complex Networks: Bounded Expansion in Random   Models and Real-World Graphs',
#        '1407.2506.txt-Discovery of Important Crossroads in Road Network using Massive Taxi   Trajectories',
#        '1408.0848.txt-Multilayer bootstrap networks',
#        '1408.4528.txt-Laplace Functional Ordering of Point Processes in Large-scale Wireless   Networks',
#        '1409.6193.txt-Estimating topological properties of weighted networks from limited   information',
#        '1409.8580.txt-Interference Functionals in Poisson Networks',
#        '1410.0446.txt-Identification of Dynamic functional brain network states Through Tensor   Decomposition',
#        '1410.0736.txt-HD-CNN: Hierarchical Deep Convolutional Neural Network for Large Scale   Visual Recognition',
#        '1410.2670.txt-Entropy NAND: Early Functional Completeness in Entropy Networks',
#        '1410.7694.txt-Dynamic Analysis of Digital Chaotic Maps via State-Mapping Networks',
#        '1411.3444.txt-Growing Scale-free Networks by a Mediation-Driven Attachment Rule',
#        '1411.4097.txt-A Game Theoretic Model for the Formation of Navigable Small-World   Networks --- the Tradeoff between Distance and Reciprocity',
#        '1411.6057.txt-Mesoscopic analysis of online social networks - The role of negative   ties',
#        '1412.4171.txt-Dynamics of Information Diffusion and Social Sensing',
#        '1412.6622.txt-Deep metric learning using Triplet network',
#        '1501.06297.txt-Geodesic convolutional neural networks on Riemannian manifolds',
#        '1502.04382.txt-Temporal Network Optimization Subject to Connectivity Constraints',
#        '1502.05058.txt-Tensor Spectral Clustering for Partitioning Higher-order Network   Structures',
#        '1503.02951.txt-Mean Field Games in Nudge Systems for Societal Networks',
#        '1503.02985.txt-SybilFrame: A Defense-in-Depth Framework for Structure-Based Sybil   Detection',
#        '1504.03342.txt-A Survey on Privacy and Security in Online Social Networks',
#        '1504.03957.txt-Optimal Hierarchical Radio Resource Management for HetNets with Flexible   Backhaul',
#        '1505.02348.txt-The Topology of Biological Networks from a Complexity Perspective',
#        '1505.03653.txt-Timed Consistent Network Updates',
#        '1505.05193.txt-Synthesising Executable Gene Regulatory Networks from Single-cell Gene   Expression Data',
#        '1506.01978.txt-Information measures and cognitive limits in multilayer navigation',
#        '1506.02438.txt-High-Dimensional Continuous Control Using Generalized Advantage   Estimation',
#        '1506.03437.txt-Topology design for stochastically-forced consensus networks',
#        '1507.02103.txt-Measuring centrality by a generalization of degree',
#        '1507.04027.txt-Fuzzy Overlapping Community Quality Metrics',
#        '1507.04606.txt-Extension of Modularity Density for Overlapping Community Structure',
#        '1507.05492.txt-Parallel Toolkit for Measuring the Quality of Network Community   Structure',
#        '1507.07583.txt-Mapping Auto-context Decision Forests to Deep ConvNets for Semantic   Segmentation',
#        '1508.04606.txt-Distributed Event-Triggered Control for Asymptotic Synchronization of   Dynamical Networks',
#        '1509.03484.txt-Local structure can identify and quantify influential global spreaders   in large scale social networks',
#        '1509.04037.txt-Measuring Partial Balance in Signed Networks',
#        '1509.08346.txt-UB-ANC Drone: A Flexible Airborne Networking and Communications Testbed',
#        '1510.04249.txt-Random Irregular Block-hierarchical Networks: Algorithms for Computation   of Main Properties',
#        '1510.07357.txt-Distributed Bare-Bones Communication in Wireless Networks',
#        '1510.08983.txt-Highway Long Short-Term Memory RNNs for Distant Speech Recognition',
#        '1510.08985.txt-Prediction-Adaptation-Correction Recurrent Neural Networks for   Low-Resource Language Speech Recognition',
#        '1511.01238.txt-The wisdom of networks: A general adaptation and learning mechanism of   complex systems: The network core triggers fast responses to known stimuli;   innovations require the slow network periphery and are encoded by   core-remodeling',
#        '1511.02683.txt-A Light CNN for Deep Face Representation with Noisy Labels',
#        '1511.03005.txt-ELDA: Towards Efficient and Lightweight Detection of Cache Pollution   Attacks in NDN',
#        '1511.04855.txt-Deep learning is a good steganalysis tool when embedding key is reused   for different images, even if there is a cover source-mismatch',
#        '1511.05432.txt-Understanding Adversarial Training: Increasing Local Stability of Neural   Nets through Robust Optimization',
#        '1511.06382.txt-Iterative Refinement of the Approximate Posterior for Directed Belief   Networks',
#        '1511.06444.txt-Universal halting times in optimization and machine learning',
#        '1511.06653.txt-Recurrent Semi-supervised Classification and Constrained Adversarial   Generation with Motion Capture Data',
#        '1511.08861.txt-Loss Functions for Neural Networks for Image Processing'],
#       dtype=object)

# %% [markdown]
# # Documentos que pertenecen al mismo tópico

# %%
totalDocs[(totalDocs['mainTopic']==topic)]['File_Name'].values
# Out:
# array(['0808.0084.txt-On the hitting times of quantum versus random walks',
#        '0907.3220.txt-Inter Genre Similarity Modelling For Automatic Music Genre   Classification',
#        '1109.2162.txt-The Complexity of the Empire Colouring Problem',
#        '1201.0490.txt-Scikit-learn: Machine Learning in Python',
#        '1204.0480.txt-Deducing Security Goals From Shape Analysis Sentences',
#        '1204.2727.txt-The Cost of Perfection for Matchings in Graphs',
#        '1206.3862.txt-Total coloring of 1-toroidal graphs of maximum degree at least 11 and no   adjacent triangles',
#        '1212.1095.txt-The projector algorithm: a simple parallel algorithm for computing   Voronoi diagrams and Delaunay graphs',
#        "1212.6751.txt-Computably Categorical Fields via Fermat's Last Theorem",
#        '1301.1027.txt-On online energy harvesting in multiple access communication systems',
#        '1306.1595.txt-Layered Separators in Minor-Closed Graph Classes with Applications',
#        '1308.4201.txt-Full-Diversity Space-Time Block Codes for Integer-Forcing Linear   Receivers',
#        '1403.2975.txt-Optimal ancilla-free Clifford+T approximation of z-rotations',
#        '1405.0149.txt-Coding Theoretic Construction of Quantum Ramp Secret Sharing',
#        '1405.0713.txt-Further result on acyclic chromatic index of planar graphs',
#        '1406.0263.txt-The "Runs" Theorem',
#        '1407.2109.txt-Planar Graphs: Random Walks and Bipartiteness Testing',
#        "1407.5374.txt-Acyclic Edge Coloring through the Lov\\'asz Local Lemma",
#        '1407.7274.txt-Isomorphism within Naive Type Theory',
#        '1408.1025.txt-Stable Throughput Region of Cognitive-Relay Networks with Imperfect   Sensing and Finite Relaying Buffer',
#        '1408.3190.txt-On the neighbour sum distinguishing index of planar graphs',
#        '1408.3976.txt-Static Analysis for Extracting Permission Checks of a Large Scale   Framework: The Challenges And Solutions for Analyzing Android',
#        '1409.0375.txt-Polynomial solvability of $NP$-complete problems',
#        '1409.8580.txt-Interference Functionals in Poisson Networks',
#        '1412.4171.txt-Dynamics of Information Diffusion and Social Sensing',
#        '1501.01042.txt-Augur: a decentralized oracle and prediction market platform',
#        '1501.05354.txt-A speed and departure time optimization algorithm for the   Pollution-Routing Problem',
#        '1502.01410.txt-On the Lexical Distinguishability of Source Code',
#        '1502.01566.txt-A Matrix Laurent Series-based Fast Fourier Transform for Blocklengths   N=4 (mod 8)',
#        '1502.02272.txt-Rigorous Deductive Argumentation for Socially Relevant Issues',
#        '1502.02800.txt-Fast integer multiplication using generalized Fermat primes',
#        '1502.04382.txt-Temporal Network Optimization Subject to Connectivity Constraints',
#        '1502.05507.txt-On asymptotically good ramp secret sharing schemes',
#        '1503.03169.txt-Dynamic Partitioning of Physical Memory Among Virtual Machines,   ASMI:Architectural Support for Memory Isolation',
#        '1504.02141.txt-Detecting Falls with X-Factor Hidden Markov Models',
#        "1504.06043.txt-Stability of Stochastic Approximations with `Controlled Markov' Noise   and Temporal Difference Learning",
#        '1504.06234.txt-Acyclic chromatic index of triangle-free 1-planar graphs',
#        '1504.06979.txt-Obstructions for three-coloring graphs without induced paths on six   vertices',
#        '1505.07368.txt-Revisiting Actor Programming in C++',
#        '1506.04391.txt-CamFlow: Managed Data-sharing for Cloud Services',
#        '1506.06305.txt-Social media affects the timing, location, and severity of school   shootings',
#        '1507.03403.txt-Time-Space Trade-offs for Triangulations and Voronoi Diagrams',
#        '1507.07402.txt-Partial resampling to approximate covering integer programs',
#        '1508.01775.txt-Cascading Power Outages Propagate Locally in an Influence Graph that is   not the Actual Grid Topology',
#        '1508.02340.txt-The Pontryagin Maximum Principle for Nonlinear Infinite Horizon Optimal   Control Problems with State Constraints',
#        '1508.06589.txt-Cooperative Spectrum Sharing Relaying Protocols With Energy Harvesting   Cognitive User',
#        '1510.04249.txt-Random Irregular Block-hierarchical Networks: Algorithms for Computation   of Main Properties',
#        '1510.07135.txt-Induced minors and well-quasi-ordering',
#        '1510.08417.txt-Monotone Projection Lower Bounds from Extended Formulation Lower Bounds',
#        '1511.03894.txt-The Game of Phishing'], dtype=object)
