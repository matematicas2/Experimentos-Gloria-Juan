# %%
import pandas as pd
import re
from pathlib import Path
import nltk
nltk.download(['punkt','stopwords','wordnet','words'])
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\A\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\A\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\A\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\A\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
from nltk.corpus import words

# %%
base_path =  Path("~").expanduser().resolve()
#base_path = Path.cwd().expanduser().resolve()
input_file_path  = base_path / 'Documents/GitHub/proyectointegrador1'

# %%
input_file_path
# Out:
# WindowsPath('C:/Users/A/Documents/GitHub/proyectointegrador1')

# %%
#workVoc_file = open("vocabulary_mayo_17.txt","r", encoding="UTF-8") 
#workVoc=workVoc_file.read()
#workVoc_file.close()
workVoc=pd.read_csv("vocabulary_mayo_17_prueba.txt", header=None) 
workVoc.insert(1,"English_word","False")
workVoc.iloc[:,0]
# Out:
# 0          aaron
# 1       aaronson
# 2          aarti
# 3            aat
# 4           aatu
# 5         aatuut
# 6            aau
# 7            aaw
# 8      aawcondit
# 9            aax
# 10       aazhang
# 11            ab
# 12           aba
# 13          abab
# 14         ababa
# 15        ababac
# 16         ababb
# 17          abac
# 18       abacaxi
# 19          abad
# 20         abadi
# 21          abak
# 22        abalon
# 23          aban
# 24       abandon
# 25         abaqu
# 26      abasekmt
# 27           abb
# 28          abba
# 29         abbaa
#          ...
# 269          acm
# 270      acmmust
# 271          acn
# 272          aco
# 273       acolor
# 274       acompi
# 275      acomput
# 276       aconst
# 277     acontrol
# 278        acopf
# 279         acou
# 280       acount
# 281       acoust
# 282          acp
# 283         acpa
# 284         acpj
# 285        acqpa
# 286     acquaint
# 287        acqui
# 288       acquir
# 289      acquisi
# ...

# %%
for w in workVoc.iloc[:,0]:
     if w in words.words():
            workVoc.iloc[:,1]="True"
print("Algunas palabras reconocidas de Inglés{}\n".format(workVoc.iloc[:1]=="True"))
# Out:
# Algunas palabras reconocidas de Inglés       0  English_word
# 0  False          True

# %%
"aau" in words.words()
# Out:
# False

# %%
workVoc
# Out:
#              0 English_word
# 0        aaron         True
# 1     aaronson         True
# 2        aarti         True
# 3          aat         True
# 4         aatu         True
# 5       aatuut         True
# 6          aau         True
# 7          aaw         True
# 8    aawcondit         True
# 9          aax         True
# 10     aazhang         True
# 11          ab         True
# 12         aba         True
# 13        abab         True
# 14       ababa         True
# 15      ababac         True
# 16       ababb         True
# 17        abac         True
# 18     abacaxi         True
# 19        abad         True
# 20       abadi         True
# 21        abak         True
# 22      abalon         True
# 23        aban         True
# 24     abandon         True
# 25       abaqu         True
# 26    abasekmt         True
# 27         abb         True
# 28        abba         True
# 29       abbaa         True
# ..         ...          ...
# 269        acm         True
# ...
